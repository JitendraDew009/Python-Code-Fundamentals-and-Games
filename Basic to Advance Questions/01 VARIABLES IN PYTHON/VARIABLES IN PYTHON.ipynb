# %% [markdown]
# # Level 1
# - Create variable name and print it
# - Store your age and print
# - Store two numbers and print their sum

# %%
# Create variable name and print it
a = "name"
print(a)
# Out:
# name

# %%
# Store your age and print
b = 25
print(b)
# Out:
# 25

# %%
# Store two numbers and print their sum
a, b = 20, 30
print(a+b)
# Out:
# 50

# %% [markdown]
# # Level 2
# - Swap two variables

# %%
a, b = 5, 10
b, a = a, b
print("a =", a)
print("b =", b)
# Out:
# a = 10
# b = 5

# %% [markdown]
# # Level 3 (Logic Building 🔥)
# - Create 3 variables and print like:
# ### My name is Jitendra and I am 21 years old

# %%
x = "My name is"
y = "Jitendra"
z = "and I am 21 years old"
print(x +" "+ y+" "+z)
# Out:
# My name is Jitendra and I am 21 years old

# %%
# Without using extra variable, swap:
a, b = 5, 10
b, a = a, b
print("a =", a)
print("b =", b)
# Out:
# a = 10
# b = 5
