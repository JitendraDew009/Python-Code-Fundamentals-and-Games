# %% [markdown]
# # Level 1
# 1. Print numbers 1 to 10
# 2. Print even numbers
# 3. Print sum of first 10 numbers

# %%
# Print numbers 1 to 10
for i in range(1,11):
    print(i)

# %%
# Print even numbers
for i in range(2,21,2):
    print(i)

# %%
# Print sum of first 10 numbers
total = 0
for i in range(1,11):
    total += i 
print(total)

# %%
# Another Method : Using sum() and range()
print(sum(range(1, 11)))

# %%
n = 10 
print(n * (n + 1) // 2)

# %% [markdown]
# # Level 2
# 1. Multiplication table
# 2. Reverse numbers
# 3. Count digits in number

# %%
# Multiplication table
for i in range(2,21,2):
    print(i)

# %%
num = []
for i in range(2,21,2):
    num.append(i)
num.reverse()
print(num)

# %%
# Count digits in number
x = "123456789"
num = ["1","2","3","4","5","6","7","8","9","0"]
count = 0
for i in x:
    if i in num:
        count += 1
print(count)

# %%
x = "123456789"
print("count", len(x))

# %% [markdown]
# # Level 3 (Logic 🔥)
# 1. Prime number check
# 2. Factorial of number
# 3. Fibonacci series

# %%
# Prime number check
x = 5
is_prime = True
if x<=1:
    is_prime = True
else:
    for i in range(2, x):
        if x % i == 0:
            is_prime = False
            break
if is_prime:
    print("Prime Number")
else:
    print("Not a Prime Number")

# %%
# Factorial of number using while
num = 4
fact = 1
while num > 0:
    fact = fact * num
    num = num - 1
print(fact)

# %%
# using for loop
n = 4
result = 1
for i in range(1, n + 1):
     result *= i
print(result)

# %%
# Fibonacci series
n = 5
fib = [0,1]
for i in range(n):
    fib.append(fib[-1]+ fib[-2])
print(fib)

# %% [markdown]
# # Level 4 (0.1% 🚀)
# 1. Pattern problems (triangle, pyramid)
# 2. Number guessing game
# 3. Menu-driven program

# %%
for i in range(10):
    print("*"*i)

# %%
n = 10
for i in range(n):
    for j in range(i,n):
        print(" ", end ="")
    for j in range(i+1):
        print("*", end="")
    for j in range(i):
        print("*", end="")
    print("")

# %%
n = 10
for i in range(n):
    for j in range(i,n):
        print(" ", end="")
    for j in range(i+1):
        print("*", end ="")
    for j in range(i):
        print("*", end="")
    print("")

# %%
# Predict Output
for i in range(3):
    print(i) # 0
    break

# %%
# Number guessing game
time = 5
for i in range(time):
    user = int(input("Enter a number 1-5 But You have 4 chance:"))

    if user == time:
        print("Guessed Right Number!")
        break
    else:
        print("Try Again")

# %%
# Menu-driven program
print("Menu" \
" 1. Chai" \
" 2. Samosa" \
" 3. Biscuit" \
" 4. Water")
order_list = []
order = int(input("Enter your order number"))
ops = {1: "Chai", 2 : "Samosa", 3 : "Biscuit", 4: "Water"}
print("You Ordered")
print(ops.get(order, "Ivalid Input"))
# Out:
# Menu 1. Chai 2. Samosa 3. Biscuit 4. Water
# You Ordered
# Chai

# %%
# Menu-driven program
print("Welcome to Madhuban Foods")
print("Menu\n" 
" 1. Chai\n" 
" 2. Samosa\n" 
" 3. Biscuit\n" \
" 4. Water\n")
order_list = []

ops = {1: "Chai", 2 : "Samosa", 3 : "Biscuit", 4: "Water"}

while True:
    try:
        order = int(input("Enter your order number (1-4): "))
        print("You selected:", ops.get(order, "Invalid Input"))

    except ValueError:
        print("Please enter a valid number.")
        continue
    
    choice = input("A. Add B. Delete C. That's all ").capitalize()

    if choice == "A":
        if order in ops:
            order_list.append(ops[order])
            print("Added :",ops[order])
        else:
            print("Please enter valid input")


    elif choice == "B":
        if order_list:
            removed_item = order_list.pop()
            print("Removed:", removed_item)
            
    elif choice == "C":
        print("Thank You for Order")
        print("Your Final Order is :", order_list)
        break
    
    else:
        print("Please enter valid input")    
print("Current Order List:", order_list)
# Out:
# Welcome to Madhuban Foods
# Menu
#  1. Chai
#  2. Samosa
#  3. Biscuit
#  4. Water
#
# You selected: Chai
# Added : Chai
# You selected: Samosa
# Added : Samosa
# You selected: Biscuit
# Thank You for Order
# Your Final Order is : ['Chai', 'Samosa']
# Current Order List: ['Chai', 'Samosa']

# %%
# Menu-driven program
print("Welcome to Madhuban Foods")
print("Menu\n"
      " 1. Chai\n"
      " 2. Samosa\n"
      " 3. Biscuit\n"
      " 4. Water\n")

ops = {1: "Chai", 2: "Samosa", 3: "Biscuit", 4: "Water"}
order_list = []

while True:
    try:
        order = int(input("Enter your order number (1-4): "))
        print("You selected:", ops.get(order, "Invalid Input"))
    except ValueError:
        print("Please enter a valid number.")
        continue

    choice = input("A. Add B. Delete C. That's all: ").capitalize()

    if choice == "A":
        if order in ops:
            order_list.append(ops[order])
            print("Added:", ops[order])
            print("Current Order List:", order_list)
        else:
            print("Invalid order number.")

    elif choice == "B":
        if order_list:
            removed_item = order_list.pop()
            print("Removed:", removed_item)
            print("Current Order List:", order_list)
        else:
            print("No items to delete.")

    elif choice == "C":
        print("Current Order List:", order_list)
        print("Thank you for your order!")
        print("Final Order List:", order_list)
        break

    else:
        print("Invalid choice. Please select A, B, or C.")

    # print("Current Order List:", order_list)
# Out:
# Welcome to Madhuban Foods
# Menu
#  1. Chai
#  2. Samosa
#  3. Biscuit
#  4. Water
#
# You selected: Chai
# Added: Chai
# Current Order List: ['Chai']
# You selected: Chai
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 20
#      17     print("Please enter a valid number.")
#      18     continue
# ---> 20 choice = input("A. Add B. Delete C. That's all: ").capitalize()
#      22 if choice == "A":
#      23     if order in ops:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
