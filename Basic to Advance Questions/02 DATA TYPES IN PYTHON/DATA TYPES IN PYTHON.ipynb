# %% [markdown]
# # Level 1
# 1. Create variables of all data types
# 2. Print their type

# %%
#  Create variables of all data types -->
# Print their type
a = 10          # int
b = 3.5         # float
c = "hello"     # string
d = True        # boolean

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# # Level 2
# 1. Convert string to int
# 2. Convert int to float

# %%
a = 10
a = int(a)
print(a)
type(a)
# Out:
# 10
# int

# %%
# Convert int to float
r = 10
r = float(r)
print(r)
type(r)
# Out:
# 10.0
# float

# %% [markdown]
# # Level 3 (Logic 🔥)
# 1. Take input from user and check type
# 2. Create list and modify it
# 3. Try modifying tuple (observe error)

# %%
# Take input from user and check type
i = input("Type something")
print("type :", type(i))
# Out:
# type : <class 'str'>

# %%
# Create list and modify it
l = ["a","b","c","d"]
l[0]= "x"
print(l)
# Out:
# ['x', 'b', 'c', 'd']

# %%
# Try modifying tuple (observe error)
tup = ("a","b","c","d")
tup[0]= "x"
print(tup)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Try modifying tuple (observe error)
#       2 tup = ("a","b","c","d")
# ----> 3 tup[0]= "x"
#       4 print(tup)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### This will show error because tuple is immutable
# #### Mutable (can change)
# - list
# - dictionary
# - set
#
# #### Immutable (cannot change)
# - int
# - float
# - string
# - tuple

# %%
# What will be output? Ans = False
x = 10
y = "10"

print(x == y)
# Out:
# False
